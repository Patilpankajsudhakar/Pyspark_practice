# %%
df = spark.read.json("/Volumes/my_files/my_schema/json_file/ex_json_files/single line json file.json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>department</th><th>employee_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>Mumbai</td><td>IT</td><td>101</td><td>Amit Sharma</td><td>65000</td></tr><tr><td>Pune</td><td>HR</td><td>102</td><td>Priya Patel</td><td>55000</td></tr><tr><td>Delhi</td><td>Finance</td><td>103</td><td>Rahul Verma</td><td>70000</td></tr><tr><td>Bangalore</td><td>IT</td><td>104</td><td>Sneha Joshi</td><td>68000</td></tr><tr><td>Hyderabad</td><td>Sales</td><td>105</td><td>Vikram Singh</td><td>60000</td></tr></tbody></table></div>

# %%
df.write.format('parquet').save("/Volumes/my_files/my_schema/parquet_files/parquet_files_2")

# %%
df2 = spark.read.parquet("/Volumes/my_files/my_schema/parquet_files/parquet_files_2")

# %%
display(df2)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>city</th><th>department</th><th>employee_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>Mumbai</td><td>IT</td><td>101</td><td>Amit Sharma</td><td>65000</td></tr><tr><td>Pune</td><td>HR</td><td>102</td><td>Priya Patel</td><td>55000</td></tr><tr><td>Delhi</td><td>Finance</td><td>103</td><td>Rahul Verma</td><td>70000</td></tr><tr><td>Bangalore</td><td>IT</td><td>104</td><td>Sneha Joshi</td><td>68000</td></tr><tr><td>Hyderabad</td><td>Sales</td><td>105</td><td>Vikram Singh</td><td>60000</td></tr></tbody></table></div>
